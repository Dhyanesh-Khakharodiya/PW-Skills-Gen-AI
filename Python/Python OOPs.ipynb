# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhyanesh-Khakharodiya/PW-Skills-Gen-AI/blob/main/Python/Python%20OOPs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Python OOPS**

# %% [markdown]
# ##**Python OOPs Questions**

# %% [markdown]
# 1. What is Object-Oriented Programming (OOP) ?

# %% [markdown]
# Ans:
# Object-Oriented Programming (OOP) is a programming paradigm that organizes software design around objects, which are instances of classes. These objects combine data (attributes) and behavior (methods) into a single unit. OOP helps in structuring programs in a modular, reusable, and scalable way.

# %% [markdown]
# 2. What is a class in OOP ?

# %% [markdown]
# Ans:
# A class in Object-Oriented Programming (OOP) is a blueprint or template used to create objects. It defines the properties (attributes) and behaviors (methods) that the objects created from it will have. Classes help organize code and promote reusability.

# %% [markdown]
# 3. What is an object in OOP ?

# %% [markdown]
# Ans:
# An object in Object-Oriented Programming (OOP) is an instance of a class. It represents a real-world entity and contains both data (attributes) and behavior (methods) defined by its class. Objects allow programs to interact with data in a structured and meaningful way.

# %% [markdown]
# 4.  What is the difference between abstraction and encapsulation ?

# %% [markdown]
# Ans:
# The difference between abstraction and encapsulation lies in their purpose.
#
# * **Abstraction** focuses on hiding unnecessary implementation details and showing only the essential features of an object. It answers what an object does.
#
# * **Encapsulation** focuses on bundling data and methods together and restricting direct access to data. It answers how the data is protected and controlled.
#
# In simple terms, abstraction reduces complexity, while encapsulation improves data security and integrity.

# %% [markdown]
# 5. What are dunder methods in Python ?

# %% [markdown]
# Ans:
# Dunder methods in Python, short for “double underscore methods,” are special methods whose names begin and end with double underscores, such as **\_\_init__** and **\_\_str__**. They allow developers to define how objects behave with built-in Python operations like initialization, printing, arithmetic, and comparison.

# %% [markdown]
# 6. Explain the concept of inheritance in OOP.

# %% [markdown]
# Ans:
# **Inheritance** in Object-Oriented Programming (OOP) is a mechanism where one class acquires the properties and behaviors of another class. The existing class is called the parent (or base) class, and the new class is called the child (or derived) class. Inheritance promotes code reuse, reduces redundancy, and allows the child class to extend or modify the functionality of the parent class.

# %% [markdown]
# 7. What is polymorphism in OOP ?

# %% [markdown]
# Ans:
# **Polymorphism** in Object-Oriented Programming (OOP) is the ability of a single interface or method name to represent different behaviors depending on the object that uses it. It allows methods to perform different tasks based on the object’s class, improving flexibility and extensibility in programs.

# %% [markdown]
# 8. How is encapsulation achieved in Python?

# %% [markdown]
# Ans:
# **Encapsulation** in Python is achieved by bundling data and methods within a class and controlling access to the data using access modifiers. Python uses naming conventions to indicate access levels:
#
# * **Public members** : accessible from anywhere
#
# * **Protected members** : prefixed with a single underscore (_)
#
# * **Private members** :  prefixed with double underscores (__)
#
# This approach helps protect data from unintended modification and improves code maintainability.

# %% [markdown]
# 9. What is a constructor in Python?

# %% [markdown]
# Ans:
# A constructor in Python is a special method named \_\_init__ that is automatically called when an object of a class is created. It is used to initialize the object’s data members with required values.

# %% [markdown]
# 10. What are class and static methods in Python ?

# %% [markdown]
# Ans:
# differ in how they access class data.
#
# A **class method** is defined using the `@classmethod` decorator and takes cls as its first parameter. It can access and modify class-level variables and is often used for alternative constructors or operations related to the class.
#
# A **static method** is defined using the `@staticmethod` decorator. It does not take self or cls as parameters and cannot access instance or class data directly. It is used for utility functions that logically belong to a class but do not depend on its state.

# %% [markdown]
# 11.  What is method overloading in Python ?

# %% [markdown]
# Ans:
# **Method overloading** in Python refers to defining multiple methods with the same name but with different parameters. However, Python does not support traditional method overloading like some other languages. Instead, it achieves similar behavior by using default arguments or variable-length arguments to handle different inputs within a single method.

# %% [markdown]
# 12. What is method overriding in OOP ?

# %% [markdown]
# Ans:
# **Method overriding** in Object-Oriented Programming (OOP) occurs when a child class provides its own implementation of a method that is already defined in its parent class. The overridden method has the same name and parameters, but its behavior is changed to suit the child class. This supports **runtime polymorphism**.

# %% [markdown]
# 13. What is a property decorator in Python ?

# %% [markdown]
# Ans:
# A **property decorator** in Python, written as `@property`, is used to define a method that can be accessed like an attribute. It allows controlled access to an object’s data by adding validation or logic while keeping a simple attribute-style interface.

# %% [markdown]
# 14. Why is polymorphism important in OOP ?

# %% [markdown]
# Ans:
# **Polymorphism** is important in Object-Oriented Programming (OOP) because it allows the same interface or method name to be used for different object types, making code more flexible and reusable. It helps reduce complexity, supports extensibility, and enables programs to work with objects in a generalized way without depending on their specific implementations.

# %% [markdown]
# 15. What is an abstract class in Python ?

# %% [markdown]
# Ans:
# An abstract class in Python is a class that cannot be instantiated directly and is meant to serve as a base class for other classes. It defines one or more abstract methods that must be implemented by its child classes.
#
# Abstract classes are created using the abc module and help enforce a common interface, ensuring that derived classes provide specific method implementations.

# %% [markdown]
# 16. What are the advantages of OOP ?

# %% [markdown]
# Ans:
# The advantages of Object-Oriented Programming (OOP) include:
#
# **Modularity** : programs are divided into classes and objects, making code easier to manage
#
# **Reusability** : existing code can be reused through inheritance
#
# **Maintainability** : changes can be made with minimal impact on other parts of the program
#
# **Scalability** : applications can be easily extended
#
# **Data security** : encapsulation helps protect data from unauthorized access
#
# These features make OOP suitable for building large and complex software systems.

# %% [markdown]
# 17. What is the difference between a class variable and an instance variable ?

# %% [markdown]
# Ans:
# The difference between a class variable and an instance variable lies in how they are defined and accessed.
#
# A c**lass variable** is shared by all objects of the class. It is defined inside the class but outside any method, and any change to it affects all instances.
#
# An **instance variable** is specific to each object. It is defined inside the constructor using self, and changes to it affect only that particular object.

# %% [markdown]
# 18.  What is multiple inheritance in Python ?

# %% [markdown]
# Ans:
# Multiple inheritance in Python is a feature where a single class can inherit from more than one parent class. This allows the child class to combine attributes and methods from multiple base classes, promoting code reuse and flexibility. Python handles conflicts in multiple inheritance using the Method Resolution Order (MRO).

# %% [markdown]
# 19. Explain the purpose of `\_\_str__` and `\_\_repr_`_ methods in Python.

# %% [markdown]
# Ans:
# The \_\_str__ and \_\_repr__ methods are special methods in Python used to define how an object is represented as a string.
#
# The \_\_str__ method returns a readable, user-friendly string representation of an object. It is mainly used for displaying information to users, such as when using the print() function.
#
# The \_\_repr__ method returns an unambiguous and detailed string representation of an object. It is primarily used for debugging and development purposes, and it should ideally return a string that can be used to recreate the object.

# %% [markdown]
# 20. What is the significance of the `super()` function in Python ?

# %% [markdown]
# Ans:
# The `super()` function in Python is used to call methods of a parent (base) class from a child (derived) class. It helps extend or reuse parent class functionality without explicitly naming the parent class. This is especially important in inheritance and multiple inheritance, as it supports proper method resolution and cleaner, more maintainable code.

# %% [markdown]
# 21. What is the significance of the __del__ method in Python ?

# %% [markdown]
# Ans:
# The **\_\_del__** method in Python is a special method known as a **destructor**. It is called automatically when an object is about to be destroyed or removed from memory. Its significance lies in performing cleanup operations, such as releasing resources or closing files, before the object is deleted.

# %% [markdown]
# 22. What is the difference between @staticmethod and @classmethod in Python ?

# %% [markdown]
# Ans:
# The difference between `@staticmethod` and `@classmethod` in Python is based on how they access class data.
#
# A **static method** does not receive any automatic first argument (self or cls). It behaves like a regular function but is placed inside a class for better organization. It cannot access or modify class or instance variables directly.
#
# A **class method** receives the class itself as the first argument (cls). It can access and modify class-level variables and is commonly used for operations related to the class rather than individual objects.

# %% [markdown]
# 23. How does polymorphism work in Python with inheritance ?

# %% [markdown]
# Ans:
# Polymorphism in Python works with inheritance by allowing a child class to redefine a method that is already present in its parent class. When the method is called using a parent class reference, Python decides at runtime which method to execute based on the object’s actual class. This behavior is known as method overriding and enables the same method name to perform different actions for different objects.

# %% [markdown]
# 24. What is method chaining in Python OOP?

# %% [markdown]
# Ans:
# Method chaining in Python OOP is a technique where multiple methods are called on the same object in a single statement. This works when each method returns the object itself (self) or another object that supports the next method call. Method chaining improves code readability and creates a fluent, compact style of programming.

# %% [markdown]
# 25. What is the purpose of the \_\_call__ method in Python?

# %% [markdown]
# Ans:
# The \_\_call__ method in Python allows an object to be called like a function. When an instance of a class is used with parentheses, Python automatically invokes its \_\_call__ method. This is useful when an object needs to behave like a function while still maintaining its own state and attributes.

# %% [markdown]
# ##**Practical Questions**

# %% [markdown]
# 1. Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog
# that overrides the speak() method to print "Bark!".

# %%
class Animal:
  def speak(self):
    print("The Animal Speaks!")

class Dog(Animal):
  def speak(self):
    print("The Dog Barks!")

# %%
a1 = Animal()
a1.speak()
# Out:
# The Animal Speaks!

# %%
d1 = Dog()
d1.speak()
# Out:
# The Dog Barks!

# %% [markdown]
# 2. Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle
# from it and implement the area() method in both.

# %%
from abc import ABC,abstractclassmethod
import math

#Abstract base class
class Shape(ABC):
  @abstractclassmethod
  def area(self):
    pass

#Child class
class Circle(Shape):
  def __init__(self,radius):
    self.radius = radius

  def area(self):
    return math.pi*(self.radius**2)


#Child class
class Rectange(Shape):
  def __init__(self,length,breadth):
    self.length = length
    self.breadth = breadth

  def area(self):
    return self.length * self.breadth

# %%
c1 = Circle(5)
c1.area()
# Out:
# 78.53981633974483

# %%
r1 = Rectange(6,3)
r1.area()
# Out:
# 18

# %% [markdown]
# 3. Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car
# and further derive a class ElectricCar that adds a battery attribute.

# %%
#GrandParent Base class

class Vehicle:
  def __init__(self,v_type):
    self.type = v_type

#Parent base class
class Car(Vehicle):
  def __init__(self,v_type,brand):
    super().__init__(v_type)
    self.brand = brand

#Child derived class
class ElectricCar(Car):
  def __init__(self,v_type,brand,battery):
    super().__init__(v_type,brand)
    self.battery = battery

# %%
ec1 = ElectricCar("4-Wheeler","Tesla",75)

# %%
ec1.brand
# Out:
# 'Tesla'

# %%
ec1.battery
# Out:
# 75

# %%
ec1.type
# Out:
# '4-Wheeler'

# %% [markdown]
# 4. Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes
# Sparrow and Penguin that override the fly() method.

# %%
#base class
class Bird:
  def fly(self):
    print("The Bird can Fly!")

#derived classes for polymorphism
class Sparrow(Bird):
  def fly(self):
    print("The sparrow flies high in the sky and it is very good at it!")

class Penguin(Bird):
  def fly(self):
    print("The Penguin cannot fly!")

# %%
birds = [Sparrow(),Penguin()]

for bird in birds:
  bird.fly()
# Out:
# The sparrow flies high in the sky and it is very good at it!
# The Penguin cannot fly!

# %% [markdown]
# 5. Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes
# balance and methods to deposit, withdraw, and check balance.

# %%
class BankAccount:
  def __init__(self,balance):
    self.__balance = balance

  def deposit(self,amount):
    self.__balance += amount

  def withdraw(self,amount):
    if amount <= self.__balance:
      self.__balance -= amount
      return True
    else:
      return False

  def check_balance(self):
    return self.__balance

# %%
##Creating a bank account
acc1 = BankAccount(10000)
acc1.check_balance()
# Out:
# 10000

# %%
## Depositing 5000
acc1.deposit(5000)
acc1.check_balance()
# Out:
# 15000

# %%
## Withdrawing 7000

acc1.withdraw(7000)
acc1.check_balance()
# Out:
# 8000

# %% [markdown]
# 6. Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar
# and Piano that implement their own version of play().

# %%
## Base class
class Instrument:
    def play(self):
        print("The instrument is being played.")


## Derived classes: Guitar & Piano
class Guitar(Instrument):
    def play(self):
        print("The guitar is playing a melody.")



class Piano(Instrument):
    def play(self):
        print("The piano is playing harmoniously.")


# Demonstrating runtime polymorphism
instruments = [Guitar(), Piano()]

for instrument in instruments:
    instrument.play()
# Out:
# The guitar is playing a melody.
# The piano is playing harmoniously.

# %% [markdown]
# 7. Create a class MathOperations with a class method add_numbers() to add two numbers and a static
# method subtract_numbers() to subtract two numbers.

# %%
class MathOperations:

  @classmethod
  def add_numbers(cls,a,b):
    return a + b

  @staticmethod
  def subtract_numbers(a,b):
    return a- b

# %%
sum_result = MathOperations.add_numbers(10, 5)
difference_result = MathOperations.subtract_numbers(10, 5)

print("Addition:", sum_result)
print("Subtraction:", difference_result)
# Out:
# Addition: 15
# Subtraction: 5

# %% [markdown]
# 8. Implement a class Person with a class method to count the total number of persons created.

# %%
class Person:
  #class level data
  p_count = 0

  def __init__(self,name):
    self.name = name
    Person.p_count += 1

  @classmethod
  def get_person_count(cls):
    return cls.p_count

# %%
p1 = Person("Dhyanesh")
print(p1.get_person_count())
p2 = Person("Chetan")
print(p1.get_person_count())
p3 = Person("Baw")
print(p1.get_person_count())
# Out:
# 1
# 2
# 3

# %% [markdown]
# 9.  Write a class Fraction with attributes numerator and denominator. Override the str method to display the
# fraction as "numerator/denominator".

# %%
class Fraction:

  def __init__(self,numerator,denominator):
    self.numerator = numerator
    self.denominator = denominator

  def __str__(self):
    return f"{self.numerator}/{self.denominator}"

# %%
frac1 = Fraction(10,5)
print(frac1)
# Out:
# 10/5

# %% [markdown]
# 10. Demonstrate operator overloading by creating a class Vector and overriding the add method to add two
# vectors.

# %%
class Vector:
  def __init__(self,x,y):
    self.x = x
    self.y = y

  def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

  def __str__(self):
        return f"({self.x}, {self.y})"

# %%
v1 = Vector(2, 3)
v2 = Vector(4, 5)

v3 = v1 + v2
print("Resultant Vector:", v3)
# Out:
# Resultant Vector: (6, 8)

# %% [markdown]
# 11. Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is
# {name} and I am {age} years old."

# %%
class Person:
  def __init__(self,name,age):
    self.name = name
    self.age = age

  def greet(self):
    print(f"Hello, my name is {self.name} and I am {self.age} years old.")

# %%
p1 = Person("Dhyanesh",28)
p1.greet()
# Out:
# Hello, my name is Dhyanesh and I am 28 years old.

# %% [markdown]
# 12. Implement a class Student with attributes name and grades. Create a method average_grade() to compute
# the average of the grades.

# %%
class Student:
  def __init__(self,name,grades):
    self.name = name
    self.grades = grades

  def average_grade(self):
    if not self.grades:
      return 0
    else:
      return sum(self.grades)/len(self.grades)

# %%
s1 = Student("Dhyan",[95,98,100,93])
s1.average_grade()
# Out:
# 96.5

# %% [markdown]
# 13. Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the
# area.

# %%
class Rectangle:
  def set_dimensions(self,length,breadth):
    self.length = length
    self.breadth = breadth

  def area(self):
    return self.length * self.breadth

# %%
r1 = Rectangle()

# %%
r1.set_dimensions(6,4)
print(f"length: {r1.length} breadth: {r1.breadth}")
print(r1.area())
# Out:
# length: 6 breadth: 4
# 24

# %% [markdown]
# 14. Create a class Employee with a method calculate_salary() that computes the salary based on hours worked
# and hourly rate. Create a derived class Manager that adds a bonus to the salary.

# %%
class Employee:
  def __init__(self,hours_worked,hourly_rate):
    self.hours_worked = hours_worked
    self.hourly_rate = hourly_rate

  def calculate_salary(self):
    return self.hours_worked * self.hourly_rate


class Manager(Employee):
  def __init__(self,hours_worked,hourly_rate,bonus):
    super().__init__(hours_worked,hourly_rate)
    self.bonus = bonus

  def calculate_salary(self):
    base_salary = super().calculate_salary()
    return base_salary + self.bonus

# %%
employee = Employee(40, 500)
manager = Manager(40, 500, 10000)

print("Employee Salary:", employee.calculate_salary())
print("Manager Salary:", manager.calculate_salary())
# Out:
# Employee Salary: 20000
# Manager Salary: 30000

# %% [markdown]
# 15. Create a class Product with attributes name, price, and quantity. Implement a method total_price() that
# calculates the total price of the product

# %%
class Product:
  def __init__(self,name,price,quantity):
    self.name = name
    self.price = price
    self.quantity = quantity

  def total_price(self):
    return self.price * self.quantity

# %%
p1 = Product("Laptop",85000,3)
p1.total_price()
# Out:
# 255000

# %% [markdown]
# 16. Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that
# implement the sound() method.

# %%
from abc import ABC, abstractmethod

class Animal(ABC):
  @abstractclassmethod
  def sound(self):
    pass

# Derived classes : Cow & Sheep
class Cow(Animal):
    def sound(self):
        print("Moo")


class Sheep(Animal):
    def sound(self):
        print("Baa")

# %%
# Example usage
animals = [Cow(), Sheep()]

for animal in animals:
    animal.sound()
# Out:
# Moo
# Baa

# %% [markdown]
# 17. Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that
# returns a formatted string with the book's details.

# %%
class Book:
  def __init__(self,title,author,year_published):
    self.title = title
    self.author = author
    self.year_published = year_published

  def get_book_info(self):
    return f"Title: {self.title}, Author: {self.author}, Year Published: {self.year_published}"

# %%
book = Book("1984", "George Orwell", 1949)

print(book.get_book_info())
# Out:
# Title: 1984, Author: George Orwell, Year Published: 1949

# %% [markdown]
# 18. Create a class House with attributes address and price. Create a derived class Mansion that adds an
# attribute number_of_rooms.

# %%
class House:
  def __init__(self,address,price):
    self.address = address
    self.price = price

class Mansion(House):
  def __init__(self,address,price,number_of_rooms):
    super().__init__(address,price)
    self.number_of_rooms = number_of_rooms

# %%
h1 = House("Mumbai",10000000)
m1 = Mansion("Surat",30000000,10)

# %%
print(f"House address: {h1.address} price: {h1.price}")
print(f"Mansion address: {m1.address} price: {m1.price} number of rooms: {m1.number_of_rooms}")
# Out:
# House address: Mumbai price: 10000000
# Mansion address: Surat price: 30000000 number of rooms: 10
